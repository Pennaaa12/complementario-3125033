# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# Leer los datos desde un archivo CSV
archivo_csv = "Extensiones.csv"  # Reemplaza con la ruta de tu archivo
df = pd.read_csv(archivo_csv)

# Convertir la columna "Usage Percentage" a flotantes si tiene el símbolo '%'
df["Usage Percentage"] = df["Usage Percentage"].str.rstrip('%').astype(float)

# Preparar los datos para regresión lineal
df = df.sort_values(by="Usage Percentage", ascending=False).reset_index(drop=True)
df["Ranking"] = np.arange(1, len(df) + 1)

# Variables independiente (Ranking) y dependiente (Usage Percentage)
X = df[["Ranking"]].values
y = df["Usage Percentage"].values

# Crear y ajustar el modelo de regresión lineal
model = LinearRegression()
model.fit(X, y)

# Generar predicciones
y_pred = model.predict(X)

# Mostrar los coeficientes del modelo
pendiente = model.coef_[0]
intercepto = model.intercept_
print(f"Pendiente (coeficiente): {pendiente}")
print(f"Intercepto: {intercepto}")

# Graficar los datos reales y la regresión lineal
plt.figure(figsize=(12, 6))
plt.scatter(df["Ranking"], df["Usage Percentage"], color="blue", label="Datos reales")
plt.plot(df["Ranking"], y_pred, color="red", label="Regresión Lineal")

# Etiquetas y título
plt.xlabel("Ranking de Extensiones")
plt.ylabel("Porcentaje de Uso (%)")
plt.title("Regresión Lineal sobre Popularidad de Extensiones en VSCode")
plt.legend()
plt.grid(True)
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# Pendiente (coeficiente): -0.8978865406006671
# Intercepto: 22.783908045977007
